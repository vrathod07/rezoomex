# %%
import selenium
from selenium.common.exceptions import NoSuchElementException
from selenium import webdriver 
from bs4 import BeautifulSoup
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
import requests
import time
import csv  
import pandas as pd
#import spacy
from re import search
import sys        
 
# appending the directory of spacy
# in the sys.path list
sys.path.append('C:/Users/User/AppData/Local/Programs/Python/Python39/Lib/site-packages')       
# now we can import mod
import spacy

# %%
def init():
      global driver
      options= Options()
      
      
      # chrome 104 location
      options.binary_location = "C:/Program Files/Google/Chrome Beta/Application/chrome.exe"
      options.add_experimental_option("detach", True) # solved error 
      options.add_argument('--no-sandbox')  
      PATH = "D:\\Anika\\VS_code\\PPL\\naturallanguageprocessing\\venv\\Include\\chromedriver.exe"
      driver = webdriver.Chrome(PATH,options=options)

# %%
df = pd.read_csv("designationcsv.csv")
print(df.head(5))

designations= df['Designation'].to_list()
print(designations)
# Out:
#                  Designation
# 0              Administrator
# 1                    testers
# 2                    Trainee
# 3                     DevOps
# 4  SQL Developer and Support
# ['Administrator', 'testers', 'Trainee', 'DevOps', 'SQL Developer and Support', 'Project engineer', 'CEO', 'CTO', 'DB Consultant', 'admin', 'Analayst', 'UI Designer', 'Front End Developer', 'Software Engineer', 'Test Engineer', 'Associate', 'Team Leader', 'IOS Devloper', 'QEA', 'QA', 'Trainee Engineer', 'Programmer Analyst', 'Senior Software Engineer', 'System Analyst', 'Project Lead', 'Project Manager', 'Program Manager', 'Doctor', 'Manager', 'Web Developer', 'Senior Software Eng', 'Senior Software Engineer', 'Deployer', 'Sys Admin', 'Architect', 'Developer', 'CSO', 'QA', 'Software Lead', 'Consulatant', 'Engineer', 'Project Engineer', 'Java developer', 'lecturer', 'Team Lead', 'Data Architect ', 'Software Developer', 'Mean Stack Developer', 'Oracle SQL Developer', 'ANIMATOR', 'ENTREPRENEUR', 'Support Engineer', 'Process Associate', 'Project Leader', 'Cloud DevOps Engineer', 'Junior Software Developer', 'SQL Data Analyst', 'Dot Net Developer Trainee', 'Test Lead', 'Senior Software Engineer', 'Associate Consultant', 'Senior Analyst', 'GS Cultural Secretary', 'Report analyst', 'Technical support manager', 'Systems engineer', 'Graduate engineer', 'Test engineer', 'Software engineer', 'Team leader', 'Team manager', 'Operations manager', 'Accountant', 'Marketing manager', 'HR', 'Data scientist']

# %%
def fetch(job):
    
    all_links=[]
    relevant_links=[]
    ##searchquery=  'https://www.coursera.org/ AND '+'data analyst'+'course'
    searchquery=  'https://www.coursera.org/ AND '+job+' course'
    google_page= driver.get("https://www.google.com/search?q="+searchquery)
    time.sleep(5)
    results = driver.find_elements(by=By.TAG_NAME,value="a");
                                                                 ##print("result =",results)
    for result in results:
                                                                 ##print(result.get_attribute("href")) 
            link= result.get_attribute("href")
            if(link is not None):
                                                                 ## print(type(link))
                                                                ##print(link)
               all_links.append(link)
                                                                 ##print(all_links)
    substring1 = "coursera"
    
   # from all links extracted find the links which have substring "coursera"
    num=0
    for link in all_links:
          
        if(search('https://maps.google.com/maps?q',link)):
                continue 
        if (search(substring1, link)):
                if(link.startswith('https://www.google.com/search?q=')):
                        continue
                elif (link.endswith('enroll')):
                        relevant_links.append(link)
                
                elif(search('professional-certificates',link)):
                        relevant_links.append(link)
                elif(search('specializations',link)):
                        relevant_links.append(link)
                elif(search(job,link)):
                        relevant_links.append(link)
                else:
                        relevant_links.append(link)
                                     
                
                
    print("========================================================")
    print("job=",job)
    #print("Relevant links : ",relevant_links)    #'https://www.coursera.org/professional-certificates/google-data-analytics#enroll',
    newlist= relevant_links
    return newlist

# %%
def remove_unwanted_urls(Coursera_links):
    newlist=[]  

    for link in Coursera_links:
                if(link=='https://www.coursera.org/' or search('coursera.org/courseraplus',link)):
                    continue
                if(search('^https://maps.google.com/',link) or search('^https://www.google.com',link) or  search('^https://accounts.google.com',link) or search('search?query=',link) or link.endswith('coursera.org/')):
                    continue
                else:
                    newlist.append(link)
    return newlist

# %%
def scrape_skills(job,url):
    mainpage= driver.get(url)
    time.sleep(5)
    print("Landed on coursera course scrape1")
    time.sleep(5)
    print()
    
    items = driver.find_elements(by=By.CLASS_NAME,value="_ontdeqt")
    
    # write to csv file
    if(len(items)>0):
        header = ['designation','skill']
        blankline=['','']
        f = open('Coursera_catalog.csv', 'a',newline='')
        writer = csv.writer(f)
        #writer.writerow(header)
        writer.writerow(blankline)
        f.close()
        
        # skills feed to csv
        for skill in items:
            sk = skill.text
            print(sk)
            row=[job,sk]
            # write a row to the csv file
            f = open('Coursera_catalog.csv', 'a',newline='')
            writer = csv.writer(f)
            writer.writerow(row)

            # close the file
        f.close()

            #<span class="_ontdeqt">Spreadsheet</span>
        print("''''''''''''''''''''''''''''''''''''''''''''''")

# %%
def choice_of_links(job,Coursera_links):
    
    empty=[]
    for link in Coursera_links:
        if(search('enroll',link)):
                    return link
                    
        elif(search('professional-certificates',link)):
                    return link
        elif(search('specializations',link)):
                    return link
        elif(search(job,link) or search(job[0:4:1],link) or search('develop',link) or search('software',link)):
            
                    return link
                    
        elif(search('courses?query=',link)):
                    return link
        elif(search('https://www.classcentral',link)):
                Coursera_links.remove(link)
        return link

# %%
def fetch_different_link(job,url):
    
    print("scrape2")
    all_links=[]
    relevant_links=[]
 
    #link=  'https://www.coursera.org/courses?query=software%20testing'
    link = url
    qpage= driver.get(link)
    source_code=driver.page_source
    

    soup = BeautifulSoup(source_code, 'html.parser')
    div = BeautifulSoup(source_code, 'html.parser').find('div', {'class':'ais-InfiniteHits'})
    #div  = soup.find_all('div',{'class':'ais-InfiniteHits'}) #cds-1 css-0 cds-3 cds-grid-item cds-48 cds-56 cds-68
    
   
    cards_block =div.find_all('li')
    time.sleep(5)
    print("total number of cards on page =",len(cards_block))
   
    #<p class="cds-111 css-z4vnns cds-113"><span class="css-1qajodb"><b>Skills you'll gain: </b></span>Computer Programming, Computer Programming Tools, Java Programming, Mobile Development, Programming Principles, Software, Software Engineering, Software Testing, Unit Testing</p>
    num=1   # extract only first 3 cards
    for tags in cards_block:
        if(num<=3):
          skills =tags.find_all('p')  #  type is <class 'bs4.element.Tag'>
          skills_results = [s.text for s in skills]  # type is string now   
          
          name_of_course= tags.find('h2')   # type is <class 'bs4.element.Tag'>
          name_of_course_results = [i.text for i in name_of_course] #type is string now
          print("num= below ",num)
          print("------------------",skills_results[0]) 
          print("-------------------",name_of_course_results[0])
          skills= extract(skills_results[0])
          feedcsv(skills,job)
          
        else:
              break
        num=num+1

# %%
def extract(str):
    # input str= " Skills you'll gain: Computer Programming,
    # Computer Programming Tools, Java Programming,
    # Mobile Development, Programming Principles, Software,
    # Software Engineering, Software Testing, Unit Testing   "     extract skills and put in csv
    
    skills= str.split(':') 
    print(skills)
    if(len(skills)>1):
     skills= skills[1].split(',')
   # print(skills)   #[' Computer Programming','Computer Programming Tools',' Java Programming','Mobile Development', ' Programming Principles', ' Software', 'Software Engineering', ' Software Testing', ' Unit Testing']
     return skills

# %%
def feedcsv(skills,job):
    #     skills=  #[' Computer Programming',
#  'Computer Programming Tools',
#  ' Java Programming',
#  'Mobile Development',
#  ' Programming Principles',
#  ' Software',
#  'Software Engineering',
#  ' Software Testing',
#  ' Unit Testing']  , job = 'Software tester'

 # skills feed to csv
   if(skills is not None):
     for skill in skills:
            sk = skill
            print(sk)
            row=[job,sk]
            # write a row to the csv file
            f = open('Coursera_catalog.csv', 'a',newline='')
            writer = csv.writer(f)
            writer.writerow(row)

# %% [markdown]
# Designation
# IT Administrator
# testers
# Trainee
# DevOps
# SQL Developer and Support
# Project engineer
# CEO
# CTO
# DB Consultant
# admin
# Analayst
# UI Designer
# Front End Developer
# Software Engineer
# Test Engineer
# Associate
# Team Leader
# IOS Devloper
# QEA
# QA
# Trainee Engineer
# Programmer Analyst
# Senior Software Engineer
# System Analyst
# Project Lead
# Project Manager
# Program Manager
# Doctor
# Manager
# Web Developer
# Senior Software Eng
# Senior Software Engineer
# Deployer
# Sys Admin
# Architect
# Developer
# CSO
# QA
# Software Lead
# Consulatant
# Engineer
# Project Engineer
# ANIMATOR
# Oracle SQL Developer

# %%
def main():
    
    init()
    for job in designations:
        #https://www.google.com/search?q=
        Coursera_links = fetch(job)
        Coursera_links= remove_unwanted_urls(Coursera_links)
            
        if(len(Coursera_links)>0):
            
            url= choice_of_links(job,Coursera_links)
            print("Chosen link : ",url)
            if(url!=[]):
                if(search('https://www.coursera.org/courses?query',url)):
                    #scrape_skills2(job,url)
                    print("goto scrape 2")
                    fetch_different_link(job,url)
                elif(url.startswith('https://www.coursera.org/courses?query')):
                     print("goto scrape 3")
                     fetch_different_link(job,url)
                else:
                    scrape_skills(job,url)
                time.sleep(5)

#<p class="cds-111 css-z4vnns cds-113"><span class="css-1qajodb"><b>Skills you'll gain: </b></span>Agile Software Development, Algorithms, Application Development, BlockChain, Cloud Computing, Cloud Infrastructure, Cloud Platforms, Cloud Storage, Collaboration, Communication, Computational Logic, Computer Architecture, Computer Graphics, Computer Networking, Computer Programming, Computer Programming Tools, Continuous Delivery, Continuous Integration, Data Management, Design and Product, DevOps, Distributed Computing Architecture, Entrepreneurship, Extract, Transform, Load, Finance, Full-Stack Web Development, Human Computer Interaction, IBM Cloud, Interactive Design, Kubernetes, Leadership and Management, Mathematical Theory &amp; Analysis, Mathematics, Network Architecture, Network Security, Operating Systems, Planning, Product Design, Product Development, Programming Principles, Project Management, Python Programming, Security Engineering, Software, Software Architecture, Software As A Service, Software Engineering, Software Engineering Tools, Software Framework, Software Testing, Statistical Programming, Strategy and Operations, Supply Chain and Logistics, System Programming, Systems Design, Theoretical Computer Science, Web Development</p>

# %%
main()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12616\2449080759.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH,options=options)
# ========================================================
# job= Java developer
# Chosen link :  https://www.coursera.org/courses?query=java
# goto scrape 3
# scrape2
# total number of cards on page = 12
# num= below  1
# ------------------ Skills you'll gain: Algorithms, Computer Architecture, Computer Graphics, Computer Networking, Computer Programming, Cryptography, Data Analysis, Data Management, Data Structures, Entrepreneurship, General Statistics, HTML and CSS, Interfaces, Java (Software Platform), Java Programming, Javascript, Leadership and Management, Machine Learning, Markov Model, Mobile Development, Network Architecture, Probability & Statistics, Problem Solving, Programming Principles, Research and Design, Security Engineering, Software, Software Engineering, Software Testing, Theoretical Computer Science, Web Design, Web Development
# ------------------- Java Programming and Software Engineering Fundamentals
# ["Skills you'll gain", ' Algorithms, Computer Architecture, Computer Graphics, Computer Networking, Computer Programming, Cryptography, Data Analysis, Data Management, Data Structures, Entrepreneurship, General Statistics, HTML and CSS, Interfaces, Java (Software Platform), Java Programming, Javascript, Leadership and Management, Machine Learning, Markov Model, Mobile Development, Network Architecture, Probability & Statistics, Problem Solving, Programming Principles, Research and Design, Security Engineering, Software, Software Engineering, Software Testing, Theoretical Computer Science, Web Design, Web Development']
#  Algorithms
#  Computer Architecture
#  Computer Graphics
#  Computer Networking
#  Computer Programming
#  Cryptography
#  Data Analysis
#  Data Management
#  Data Structures
#  Entrepreneurship
#  General Statistics
#  HTML and CSS
#  Interfaces
#  Java (Software Platform)
#  Java Programming
#  Javascript
#  Leadership and Management
#  Machine Learning
#  Markov Model
#  Mobile Development
#  Network Architecture
#  Probability & Statistics
#  Problem Solving
#  Programming Principles
#  Research and Design
#  Security Engineering
#  Software
#  Software Engineering
#  Software Testing
#  Theoretical Computer Science
#  Web Design
#  Web Development
# num= below  2
# ------------------ Skills you'll gain: Algorithms, Application Development, Communication, Computational Logic, Computer Architecture, Computer Programming, Computer Programming Tools, Data Management, Data Structures, Front-End Web Development, HTML and CSS, Hardware Design, Human Computer Interaction, Javascript, Journalism, Mathematical Theory & Analysis, Mathematics, Mobile Development, Mobile Development Tools, Operations Research, Other Web Frameworks, Programming Principles, React (web framework), Research and Design, Software Architecture, Software Engineering, Software Engineering Tools, Software Testing, Strategy and Operations, Theoretical Computer Science, User Experience, Web Design, Web Development
# ------------------- Meta React Native
# ["Skills you'll gain", ' Algorithms, Application Development, Communication, Computational Logic, Computer Architecture, Computer Programming, Computer Programming Tools, Data Management, Data Structures, Front-End Web Development, HTML and CSS, Hardware Design, Human Computer Interaction, Javascript, Journalism, Mathematical Theory & Analysis, Mathematics, Mobile Development, Mobile Development Tools, Operations Research, Other Web Frameworks, Programming Principles, React (web framework), Research and Design, Software Architecture, Software Engineering, Software Engineering Tools, Software Testing, Strategy and Operations, Theoretical Computer Science, User Experience, Web Design, Web Development']
#  Algorithms
#  Application Development
#  Communication
#  Computational Logic
#  Computer Architecture
#  Computer Programming
#  Computer Programming Tools
#  Data Management
#  Data Structures
#  Front-End Web Development
#  HTML and CSS
#  Hardware Design
#  Human Computer Interaction
#  Javascript
#  Journalism
#  Mathematical Theory & Analysis
#  Mathematics
#  Mobile Development
#  Mobile Development Tools
#  Operations Research
#  Other Web Frameworks
#  Programming Principles
#  React (web framework)
#  Research and Design
#  Software Architecture
#  Software Engineering
#  Software Engineering Tools
#  Software Testing
#  Strategy and Operations
#  Theoretical Computer Science
#  User Experience
#  Web Design
#  Web Development
# num= below  3
# ------------------ Skills you'll gain: Algorithms, Computer Architecture, Computer Graphics, Computer Programming, Cryptography, Data Management, Data Structures, Entrepreneurship, Hardware Design, Java (Software Platform), Java Programming, Leadership and Management, Mobile Development, Object-Oriented Programming, Problem Solving, Programming Principles, Research and Design, Security Engineering, Software, Theoretical Computer Science, Web Development
# ------------------- Object Oriented Programming in Java
# ["Skills you'll gain", ' Algorithms, Computer Architecture, Computer Graphics, Computer Programming, Cryptography, Data Management, Data Structures, Entrepreneurship, Hardware Design, Java (Software Platform), Java Programming, Leadership and Management, Mobile Development, Object-Oriented Programming, Problem Solving, Programming Principles, Research and Design, Security Engineering, Software, Theoretical Computer Science, Web Development']
#  Algorithms
#  Computer Architecture
#  Computer Graphics
#  Computer Programming
#  Cryptography
#  Data Management
#  Data Structures
#  Entrepreneurship
#  Hardware Design
#  Java (Software Platform)
#  Java Programming
#  Leadership and Management
#  Mobile Development
#  Object-Oriented Programming
#  Problem Solving
#  Programming Principles
#  Research and Design
#  Security Engineering
#  Software
#  Theoretical Computer Science
#  Web Development
# ========================================================
# job= lecturer
# Chosen link :  https://www.coursera.org/courses?query=teaching
# goto scrape 3
# scrape2
# total number of cards on page = 12
# num= below  1
# ------------------ Free
# ------------------- Foundations of Teaching for Learning: Being a Teacher
# ['Free']
# num= below  2
# ------------------ Free
# ------------------- Learning to Teach Online
# ['Free']
# num= below  3
# ------------------ Free
# ------------------- Get Interactive: Practical Teaching with Technology
# ['Free']
# ========================================================
# job= Team Lead
# Chosen link :  https://www.coursera.org/specializations/leading-teams
# Landed on coursera course scrape1
#
# Vision Alignment
# Talent Management
# Goals and Rewards
# Motivate Employees
# Leadership
# goal setting
# Communication
# Leadership Development
# Onboarding
# Coaching
# Recruitment
# Management
# ''''''''''''''''''''''''''''''''''''''''''''''
# ========================================================
# job= Data Architect
# Chosen link :  https://www.coursera.org/articles/data-architect
# Landed on coursera course scrape1
#
# ========================================================
# job= Software Developer
# Chosen link :  https://www.coursera.org/browse/computer-science/software-development
# Landed on coursera course scrape1
#
# ========================================================
# job= Mean Stack Developer
# Chosen link :  https://www.coursera.org/courses?query=full%20stack%20web%20development
# goto scrape 3
# scrape2
# total number of cards on page = 12
# num= below  1
# ------------------ Skills you'll gain: Application Development, Back-End Web Development, BlockChain, Cloud Applications, Cloud Computing, Cloud Foundry, Cloud Infrastructure, Cloud Platforms, Cloud Storage, Computational Logic, Computer Architecture, Computer Graphics, Computer Networking, Computer Programming, Computer Programming Tools, Continuous Delivery, Continuous Integration, Data Management, Database Administration, Database Application, Database Design, Databases, DevOps, Devops Tools, Distributed Computing Architecture, Extract, Transform, Load, Finance, Front-End Web Development, Full-Stack Web Development, Github, HTML and CSS, Human Computer Interaction, IBM Cloud, Interactive Design, Javascript, Kubernetes, Mathematical Theory & Analysis, Mathematics, Network Architecture, Network Security, NoSQL, Operating Systems, Other Web Frameworks, Python Programming, React (web framework), SQL, Security Engineering, Software, Software Architecture, Software As A Service, Software Engineering, Software Framework, Software Testing, Statistical Programming, System Programming, Systems Design, Theoretical Computer Science, Web Design, Web Development, Web Development Tools
# ------------------- IBM Full Stack Software Developer
# ["Skills you'll gain", ' Application Development, Back-End Web Development, BlockChain, Cloud Applications, Cloud Computing, Cloud Foundry, Cloud Infrastructure, Cloud Platforms, Cloud Storage, Computational Logic, Computer Architecture, Computer Graphics, Computer Networking, Computer Programming, Computer Programming Tools, Continuous Delivery, Continuous Integration, Data Management, Database Administration, Database Application, Database Design, Databases, DevOps, Devops Tools, Distributed Computing Architecture, Extract, Transform, Load, Finance, Front-End Web Development, Full-Stack Web Development, Github, HTML and CSS, Human Computer Interaction, IBM Cloud, Interactive Design, Javascript, Kubernetes, Mathematical Theory & Analysis, Mathematics, Network Architecture, Network Security, NoSQL, Operating Systems, Other Web Frameworks, Python Programming, React (web framework), SQL, Security Engineering, Software, Software Architecture, Software As A Service, Software Engineering, Software Framework, Software Testing, Statistical Programming, System Programming, Systems Design, Theoretical Computer Science, Web Design, Web Development, Web Development Tools']
#  Application Development
#  Back-End Web Development
#  BlockChain
#  Cloud Applications
#  Cloud Computing
#  Cloud Foundry
#  Cloud Infrastructure
#  Cloud Platforms
#  Cloud Storage
#  Computational Logic
#  Computer Architecture
#  Computer Graphics
#  Computer Networking
#  Computer Programming
#  Computer Programming Tools
#  Continuous Delivery
#  Continuous Integration
#  Data Management
#  Database Administration
#  Database Application
#  Database Design
#  Databases
#  DevOps
#  Devops Tools
#  Distributed Computing Architecture
#  Extract
#  Transform
#  Load
#  Finance
#  Front-End Web Development
#  Full-Stack Web Development
#  Github
#  HTML and CSS
#  Human Computer Interaction
#  IBM Cloud
#  Interactive Design
#  Javascript
#  Kubernetes
#  Mathematical Theory & Analysis
#  Mathematics
#  Network Architecture
#  Network Security
#  NoSQL
#  Operating Systems
#  Other Web Frameworks
#  Python Programming
#  React (web framework)
#  SQL
#  Security Engineering
#  Software
#  Software Architecture
#  Software As A Service
#  Software Engineering
#  Software Framework
#  Software Testing
#  Statistical Programming
#  System Programming
#  Systems Design
#  Theoretical Computer Science
#  Web Design
#  Web Development
#  Web Development Tools
# num= below  2
# ------------------ Skills you'll gain: Application Development, Authentication, Cloud Computing, Computer Programming, Computer Programming Tools, Databases, Distributed Computing Architecture, Front-End Web Development, Github, Human Computer Interaction, Javascript, Mobile Development, Mongodb, NoSQL, Operating Systems, Programming Principles, React (web framework), Security Engineering, Software Architecture, Software As A Service, Software Engineering, Software Engineering Tools, Software Security, System Security, Theoretical Computer Science, User Experience, Web Design, Web Development
# ------------------- Full-Stack Web Development with React
# ["Skills you'll gain", ' Application Development, Authentication, Cloud Computing, Computer Programming, Computer Programming Tools, Databases, Distributed Computing Architecture, Front-End Web Development, Github, Human Computer Interaction, Javascript, Mobile Development, Mongodb, NoSQL, Operating Systems, Programming Principles, React (web framework), Security Engineering, Software Architecture, Software As A Service, Software Engineering, Software Engineering Tools, Software Security, System Security, Theoretical Computer Science, User Experience, Web Design, Web Development']
#  Application Development
#  Authentication
#  Cloud Computing
#  Computer Programming
#  Computer Programming Tools
#  Databases
#  Distributed Computing Architecture
#  Front-End Web Development
#  Github
#  Human Computer Interaction
#  Javascript
#  Mobile Development
#  Mongodb
#  NoSQL
#  Operating Systems
#  Programming Principles
#  React (web framework)
#  Security Engineering
#  Software Architecture
#  Software As A Service
#  Software Engineering
#  Software Engineering Tools
#  Software Security
#  System Security
#  Theoretical Computer Science
#  User Experience
#  Web Design
#  Web Development
# num= below  3
# ------------------ Skills you'll gain: Angular, Application Development, Cloud Computing, Computer Programming, Computer Programming Tools, Databases, Distributed Computing Architecture, Human Computer Interaction, Javascript, Mobile Development, Mongodb, NoSQL, Operating Systems, Other Programming Languages, Programming Principles, Security Engineering, Software Architecture, Software As A Service, Software Engineering, Software Engineering Tools, Software Security, System Security, Theoretical Computer Science, User Experience, Web Design, Web Development
# ------------------- Full Stack Web Development with Angular
# ["Skills you'll gain", ' Angular, Application Development, Cloud Computing, Computer Programming, Computer Programming Tools, Databases, Distributed Computing Architecture, Human Computer Interaction, Javascript, Mobile Development, Mongodb, NoSQL, Operating Systems, Other Programming Languages, Programming Principles, Security Engineering, Software Architecture, Software As A Service, Software Engineering, Software Engineering Tools, Software Security, System Security, Theoretical Computer Science, User Experience, Web Design, Web Development']
#  Angular
#  Application Development
#  Cloud Computing
#  Computer Programming
#  Computer Programming Tools
#  Databases
#  Distributed Computing Architecture
#  Human Computer Interaction
#  Javascript
#  Mobile Development
#  Mongodb
#  NoSQL
#  Operating Systems
#  Other Programming Languages
#  Programming Principles
#  Security Engineering
#  Software Architecture
#  Software As A Service
#  Software Engineering
#  Software Engineering Tools
#  Software Security
#  System Security
#  Theoretical Computer Science
#  User Experience
#  Web Design
#  Web Development
# ========================================================
# job= ENTREPRENEUR
# Chosen link :  https://www.coursera.org/browse/business/entrepreneurship
# Landed on coursera course scrape1
#
# ========================================================
# job= Support Engineer
# Chosen link :  https://www.coursera.org/professional-certificates/google-it-support
# Landed on coursera course scrape1
#
# Debugging
# Encryption Algorithms and Techniques
# Customer Service
# Network Protocols
# Cloud Computing
# Binary Code
#
#
#
#
#
#
# ''''''''''''''''''''''''''''''''''''''''''''''
# ========================================================
# job= Process Associate
# Chosen link :  https://www.thinkimpact.com/coursera-review/
# Landed on coursera course scrape1
#
# ========================================================
# job= Project Leader
# Chosen link :  https://www.coursera.org/courses?query=project%20management
# goto scrape 3
# scrape2
# total number of cards on page = 12
# num= below  1
# ------------------ Skills you'll gain: Agile Software Development, Application Development, Budget Management, Business Analysis, Business Process Management, Business Psychology, Change Management, Communication, Culture, Data Analysis, Data Visualization, Design and Product, Entrepreneurship, Finance, Human Resources, Leadership Development, Leadership and Management, Marketing, Operations Management, Operations Research, Organizational Development, Planning, Probability & Statistics, Procurement, Product Design, Project, Project Management, Public Relations, Research and Design, Risk, Risk Management, Sales, Software, Software Engineering, Software Engineering Tools, Software Testing, Spreadsheet Software, Statistical Tests, Storytelling, Strategy, Strategy and Operations, Supply Chain Systems, Supply Chain and Logistics, User Experience, Vendor Management, Writing
# ------------------- Google Project Management:
# ["Skills you'll gain", ' Agile Software Development, Application Development, Budget Management, Business Analysis, Business Process Management, Business Psychology, Change Management, Communication, Culture, Data Analysis, Data Visualization, Design and Product, Entrepreneurship, Finance, Human Resources, Leadership Development, Leadership and Management, Marketing, Operations Management, Operations Research, Organizational Development, Planning, Probability & Statistics, Procurement, Product Design, Project, Project Management, Public Relations, Research and Design, Risk, Risk Management, Sales, Software, Software Engineering, Software Engineering Tools, Software Testing, Spreadsheet Software, Statistical Tests, Storytelling, Strategy, Strategy and Operations, Supply Chain Systems, Supply Chain and Logistics, User Experience, Vendor Management, Writing']
#  Agile Software Development
#  Application Development
#  Budget Management
#  Business Analysis
#  Business Process Management
#  Business Psychology
#  Change Management
#  Communication
#  Culture
#  Data Analysis
#  Data Visualization
#  Design and Product
#  Entrepreneurship
#  Finance
#  Human Resources
#  Leadership Development
#  Leadership and Management
#  Marketing
#  Operations Management
#  Operations Research
#  Organizational Development
#  Planning
#  Probability & Statistics
#  Procurement
#  Product Design
#  Project
#  Project Management
#  Public Relations
#  Research and Design
#  Risk
#  Risk Management
#  Sales
#  Software
#  Software Engineering
#  Software Engineering Tools
#  Software Testing
#  Spreadsheet Software
#  Statistical Tests
#  Storytelling
#  Strategy
#  Strategy and Operations
#  Supply Chain Systems
#  Supply Chain and Logistics
#  User Experience
#  Vendor Management
#  Writing
# num= below  2
# ------------------ Skills you'll gain: Human Resources, Supply Chain and Logistics, Organizational Development, Software Engineering, Agile Management, Planning, Operations Management, Sales, Strategy and Operations, Culture, Leadership and Management, Business Process Management, Communication, Project Management, Project, Software Engineering Tools, Entrepreneurship, Change Management, Leadership, Organizational Structure, Business Psychology
# ------------------- Foundations of Project Management
# ["Skills you'll gain", ' Human Resources, Supply Chain and Logistics, Organizational Development, Software Engineering, Agile Management, Planning, Operations Management, Sales, Strategy and Operations, Culture, Leadership and Management, Business Process Management, Communication, Project Management, Project, Software Engineering Tools, Entrepreneurship, Change Management, Leadership, Organizational Structure, Business Psychology']
#  Human Resources
#  Supply Chain and Logistics
#  Organizational Development
#  Software Engineering
#  Agile Management
#  Planning
#  Operations Management
#  Sales
#  Strategy and Operations
#  Culture
#  Leadership and Management
#  Business Process Management
#  Communication
#  Project Management
#  Project
#  Software Engineering Tools
#  Entrepreneurship
#  Change Management
#  Leadership
#  Organizational Structure
#  Business Psychology
# num= below  3
# ------------------ Skills you'll gain: Budget Management, Change Management, Communication, Conflict Management, Cost, Entrepreneurship, Finance, Human Resources, Leadership and Management, Operations Research, Planning, Probability & Statistics, Project Management, Research and Design, Risk, Risk Management, Schedule, Statistical Tests, Strategy and Operations, Supply Chain and Logistics
# ------------------- Project Management Principles and Practices
# ["Skills you'll gain", ' Budget Management, Change Management, Communication, Conflict Management, Cost, Entrepreneurship, Finance, Human Resources, Leadership and Management, Operations Research, Planning, Probability & Statistics, Project Management, Research and Design, Risk, Risk Management, Schedule, Statistical Tests, Strategy and Operations, Supply Chain and Logistics']
#  Budget Management
#  Change Management
#  Communication
#  Conflict Management
#  Cost
#  Entrepreneurship
#  Finance
#  Human Resources
#  Leadership and Management
#  Operations Research
#  Planning
#  Probability & Statistics
#  Project Management
#  Research and Design
#  Risk
#  Risk Management
#  Schedule
#  Statistical Tests
#  Strategy and Operations
#  Supply Chain and Logistics
# ========================================================
# job= Cloud DevOps Engineer
# Chosen link :  https://www.coursera.org/professional-certificates/sre-devops-engineer-google-cloud
# Landed on coursera course scrape1
#
# Google Compute Engine
# Google App Engine (GAE)
# Google Cloud Platform
# Cloud Computing
# SRE Culture
# Business Value
#
#
#
#
#
#
# ''''''''''''''''''''''''''''''''''''''''''''''
# ========================================================
# job= Junior Software Developer
# Chosen link :  https://www.coursera.org/browse/computer-science/software-development
# Landed on coursera course scrape1
#
# ========================================================
# job= SQL Data Analyst
# Chosen link :  https://www.coursera.org/learn/sql-for-data-science
# Landed on coursera course scrape1
#
# Data Science
# Data Analysis
# Sqlite
# SQL
# ''''''''''''''''''''''''''''''''''''''''''''''
# ========================================================
# job= Dot Net Developer Trainee
# Chosen link :  https://www.coursera.org/lecture/develop-windows-apps-gcp/introducing-net-core-JkSfp
# Landed on coursera course scrape1
#
# ========================================================
# job= Test Lead
# Chosen link :  https://www.coursera.org/courses?query=software%20testing
# goto scrape 3
# scrape2
# total number of cards on page = 12
# num= below  1
# ------------------ Skills you'll gain: .Properties, Communication, Computer Programming, Computer Programming Tools, Java Programming, Journalism, Mobile Development, Programming Principles, Software, Software Engineering, Software Testing, Unit Testing
# ------------------- Software Testing and Automation
# ["Skills you'll gain", ' .Properties, Communication, Computer Programming, Computer Programming Tools, Java Programming, Journalism, Mobile Development, Programming Principles, Software, Software Engineering, Software Testing, Unit Testing']
#  .Properties
#  Communication
#  Computer Programming
#  Computer Programming Tools
#  Java Programming
#  Journalism
#  Mobile Development
#  Programming Principles
#  Software
#  Software Engineering
#  Software Testing
#  Unit Testing
# num= below  2
# ------------------ Skills you'll gain: Software Engineering, Computer Programming Tools, Software Testing, Mobile Development, Unit Testing, Computer Programming, Java Programming, Software
# ------------------- Introduction to Software Testing
# ["Skills you'll gain", ' Software Engineering, Computer Programming Tools, Software Testing, Mobile Development, Unit Testing, Computer Programming, Java Programming, Software']
#  Software Engineering
#  Computer Programming Tools
#  Software Testing
#  Mobile Development
#  Unit Testing
#  Computer Programming
#  Java Programming
#  Software
# num= below  3
# ------------------ Skills you'll gain: Application Development, Cloud Computing, Cloud Platforms, Computational Logic, Computational Thinking, Computer Programming, Computer Programming Tools, Data Structures, Debugging, Github, Google Cloud Platform, Leadership and Management, Mathematical Theory & Analysis, Mathematics, Other Programming Languages, Programming Principles, Python Programming, Software, Software Engineering, Software Engineering Tools, Software Testing, Statistical Programming, Test Automation, Theoretical Computer Science, Version Control
# ------------------- Google IT Automation with Python
# ["Skills you'll gain", ' Application Development, Cloud Computing, Cloud Platforms, Computational Logic, Computational Thinking, Computer Programming, Computer Programming Tools, Data Structures, Debugging, Github, Google Cloud Platform, Leadership and Management, Mathematical Theory & Analysis, Mathematics, Other Programming Languages, Programming Principles, Python Programming, Software, Software Engineering, Software Engineering Tools, Software Testing, Statistical Programming, Test Automation, Theoretical Computer Science, Version Control']
#  Application Development
#  Cloud Computing
#  Cloud Platforms
#  Computational Logic
#  Computational Thinking
#  Computer Programming
#  Computer Programming Tools
#  Data Structures
#  Debugging
#  Github
#  Google Cloud Platform
#  Leadership and Management
#  Mathematical Theory & Analysis
#  Mathematics
#  Other Programming Languages
#  Programming Principles
#  Python Programming
#  Software
#  Software Engineering
#  Software Engineering Tools
#  Software Testing
#  Statistical Programming
#  Test Automation
#  Theoretical Computer Science
#  Version Control
# ========================================================
# job= Senior Software Engineer
# Chosen link :  https://www.coursera.org/courses?query=software%20engineering
# goto scrape 3
# scrape2
# total number of cards on page = 12
# num= below  1
# ------------------ Skills you'll gain: Agile Software Development, Algorithms, Application Development, BlockChain, Cloud Computing, Cloud Infrastructure, Cloud Platforms, Cloud Storage, Collaboration, Communication, Computational Logic, Computer Architecture, Computer Graphics, Computer Networking, Computer Programming, Computer Programming Tools, Continuous Delivery, Continuous Integration, Data Management, Design and Product, DevOps, Distributed Computing Architecture, Entrepreneurship, Extract, Transform, Load, Finance, Full-Stack Web Development, Human Computer Interaction, IBM Cloud, Interactive Design, Journalism, Kubernetes, Leadership and Management, Mathematical Theory & Analysis, Mathematics, Network Architecture, Network Security, Operating Systems, Planning, Product Design, Product Development, Programming Principles, Project Management, Python Programming, Security Engineering, Software Architecture, Software As A Service, Software Engineering, Software Engineering Tools, Software Framework, Software Testing, Statistical Programming, Strategy and Operations, Supply Chain and Logistics, System Programming, Systems Design, Theoretical Computer Science, Web Development
# ------------------- IBM DevOps and Software Engineering
# ["Skills you'll gain", ' Agile Software Development, Algorithms, Application Development, BlockChain, Cloud Computing, Cloud Infrastructure, Cloud Platforms, Cloud Storage, Collaboration, Communication, Computational Logic, Computer Architecture, Computer Graphics, Computer Networking, Computer Programming, Computer Programming Tools, Continuous Delivery, Continuous Integration, Data Management, Design and Product, DevOps, Distributed Computing Architecture, Entrepreneurship, Extract, Transform, Load, Finance, Full-Stack Web Development, Human Computer Interaction, IBM Cloud, Interactive Design, Journalism, Kubernetes, Leadership and Management, Mathematical Theory & Analysis, Mathematics, Network Architecture, Network Security, Operating Systems, Planning, Product Design, Product Development, Programming Principles, Project Management, Python Programming, Security Engineering, Software Architecture, Software As A Service, Software Engineering, Software Engineering Tools, Software Framework, Software Testing, Statistical Programming, Strategy and Operations, Supply Chain and Logistics, System Programming, Systems Design, Theoretical Computer Science, Web Development']
#  Agile Software Development
#  Algorithms
#  Application Development
#  BlockChain
#  Cloud Computing
#  Cloud Infrastructure
#  Cloud Platforms
#  Cloud Storage
#  Collaboration
#  Communication
#  Computational Logic
#  Computer Architecture
#  Computer Graphics
#  Computer Networking
#  Computer Programming
#  Computer Programming Tools
#  Continuous Delivery
#  Continuous Integration
#  Data Management
#  Design and Product
#  DevOps
#  Distributed Computing Architecture
#  Entrepreneurship
#  Extract
#  Transform
#  Load
#  Finance
#  Full-Stack Web Development
#  Human Computer Interaction
#  IBM Cloud
#  Interactive Design
#  Journalism
#  Kubernetes
#  Leadership and Management
#  Mathematical Theory & Analysis
#  Mathematics
#  Network Architecture
#  Network Security
#  Operating Systems
#  Planning
#  Product Design
#  Product Development
#  Programming Principles
#  Project Management
#  Python Programming
#  Security Engineering
#  Software Architecture
#  Software As A Service
#  Software Engineering
#  Software Engineering Tools
#  Software Framework
#  Software Testing
#  Statistical Programming
#  Strategy and Operations
#  Supply Chain and Logistics
#  System Programming
#  Systems Design
#  Theoretical Computer Science
#  Web Development
# num= below  2
# ------------------ Skills you'll gain: Algorithms, Application Development, Communication, Computational Logic, Computer Architecture, Computer Programming, Computer Programming Tools, Data Management, Data Structures, Front-End Web Development, HTML and CSS, Hardware Design, Human Computer Interaction, Javascript, Journalism, Mathematical Theory & Analysis, Mathematics, Mobile Development, Mobile Development Tools, Operations Research, Other Web Frameworks, Programming Principles, React (web framework), Research and Design, Software Architecture, Software Engineering, Software Engineering Tools, Software Testing, Strategy and Operations, Theoretical Computer Science, User Experience, Web Design, Web Development
# ------------------- Meta React Native
# ["Skills you'll gain", ' Algorithms, Application Development, Communication, Computational Logic, Computer Architecture, Computer Programming, Computer Programming Tools, Data Management, Data Structures, Front-End Web Development, HTML and CSS, Hardware Design, Human Computer Interaction, Javascript, Journalism, Mathematical Theory & Analysis, Mathematics, Mobile Development, Mobile Development Tools, Operations Research, Other Web Frameworks, Programming Principles, React (web framework), Research and Design, Software Architecture, Software Engineering, Software Engineering Tools, Software Testing, Strategy and Operations, Theoretical Computer Science, User Experience, Web Design, Web Development']
#  Algorithms
#  Application Development
#  Communication
#  Computational Logic
#  Computer Architecture
#  Computer Programming
#  Computer Programming Tools
#  Data Management
#  Data Structures
#  Front-End Web Development
#  HTML and CSS
#  Hardware Design
#  Human Computer Interaction
#  Javascript
#  Journalism
#  Mathematical Theory & Analysis
#  Mathematics
#  Mobile Development
#  Mobile Development Tools
#  Operations Research
#  Other Web Frameworks
#  Programming Principles
#  React (web framework)
#  Research and Design
#  Software Architecture
#  Software Engineering
#  Software Engineering Tools
#  Software Testing
#  Strategy and Operations
#  Theoretical Computer Science
#  User Experience
#  Web Design
#  Web Development
# num= below  3
# ------------------ Skills you'll gain: Application Development, Back-End Web Development, BlockChain, Cloud Applications, Cloud Computing, Cloud Foundry, Cloud Infrastructure, Cloud Platforms, Cloud Storage, Computational Logic, Computer Architecture, Computer Graphics, Computer Networking, Computer Programming, Computer Programming Tools, Continuous Delivery, Continuous Integration, Data Management, Database Administration, Database Application, Database Design, Databases, DevOps, Devops Tools, Distributed Computing Architecture, Extract, Transform, Load, Finance, Front-End Web Development, Full-Stack Web Development, Github, HTML and CSS, Human Computer Interaction, IBM Cloud, Interactive Design, Javascript, Kubernetes, Mathematical Theory & Analysis, Mathematics, Network Architecture, Network Security, NoSQL, Operating Systems, Other Web Frameworks, Python Programming, React (web framework), SQL, Security Engineering, Software, Software Architecture, Software As A Service, Software Engineering, Software Framework, Software Testing, Statistical Programming, System Programming, Systems Design, Theoretical Computer Science, Web Design, Web Development, Web Development Tools
# ------------------- IBM Full Stack Software Developer
# ["Skills you'll gain", ' Application Development, Back-End Web Development, BlockChain, Cloud Applications, Cloud Computing, Cloud Foundry, Cloud Infrastructure, Cloud Platforms, Cloud Storage, Computational Logic, Computer Architecture, Computer Graphics, Computer Networking, Computer Programming, Computer Programming Tools, Continuous Delivery, Continuous Integration, Data Management, Database Administration, Database Application, Database Design, Databases, DevOps, Devops Tools, Distributed Computing Architecture, Extract, Transform, Load, Finance, Front-End Web Development, Full-Stack Web Development, Github, HTML and CSS, Human Computer Interaction, IBM Cloud, Interactive Design, Javascript, Kubernetes, Mathematical Theory & Analysis, Mathematics, Network Architecture, Network Security, NoSQL, Operating Systems, Other Web Frameworks, Python Programming, React (web framework), SQL, Security Engineering, Software, Software Architecture, Software As A Service, Software Engineering, Software Framework, Software Testing, Statistical Programming, System Programming, Systems Design, Theoretical Computer Science, Web Design, Web Development, Web Development Tools']
#  Application Development
#  Back-End Web Development
#  BlockChain
#  Cloud Applications
#  Cloud Computing
#  Cloud Foundry
#  Cloud Infrastructure
#  Cloud Platforms
#  Cloud Storage
#  Computational Logic
#  Computer Architecture
#  Computer Graphics
#  Computer Networking
#  Computer Programming
#  Computer Programming Tools
#  Continuous Delivery
#  Continuous Integration
#  Data Management
#  Database Administration
#  Database Application
#  Database Design
#  Databases
#  DevOps
#  Devops Tools
#  Distributed Computing Architecture
#  Extract
#  Transform
#  Load
#  Finance
#  Front-End Web Development
#  Full-Stack Web Development
#  Github
#  HTML and CSS
#  Human Computer Interaction
#  IBM Cloud
#  Interactive Design
#  Javascript
#  Kubernetes
#  Mathematical Theory & Analysis
#  Mathematics
#  Network Architecture
#  Network Security
#  NoSQL
#  Operating Systems
#  Other Web Frameworks
#  Python Programming
#  React (web framework)
#  SQL
#  Security Engineering
#  Software
#  Software Architecture
#  Software As A Service
#  Software Engineering
#  Software Framework
#  Software Testing
#  Statistical Programming
#  System Programming
#  Systems Design
#  Theoretical Computer Science
#  Web Design
#  Web Development
#  Web Development Tools
# ========================================================
# job= Associate Consultant
# Chosen link :  https://www.coursera.org/courses?query=management%20consulting
# goto scrape 3
# scrape2
# total number of cards on page = 12
# num= below  1
# ------------------ Skills you'll gain: Career, Collaboration, Communication, Leadership and Management
# ------------------- Management Consulting
# ["Skills you'll gain", ' Career, Collaboration, Communication, Leadership and Management']
#  Career
#  Collaboration
#  Communication
#  Leadership and Management
# num= below  2
# ------------------ Skills you'll gain: Communication, Leadership and Management, Collaboration
# ------------------- Introduction to Management Consulting
# ["Skills you'll gain", ' Communication, Leadership and Management, Collaboration']
#  Communication
#  Leadership and Management
#  Collaboration
# num= below  3
# ------------------ Skills you'll gain: Human Resources, Supply Chain and Logistics, Organizational Development, Software Engineering, Agile Management, Planning, Operations Management, Sales, Strategy and Operations, Culture, Leadership and Management, Business Process Management, Communication, Project Management, Project, Software Engineering Tools, Entrepreneurship, Change Management, Leadership, Organizational Structure, Business Psychology
# ------------------- Foundations of Project Management
# ["Skills you'll gain", ' Human Resources, Supply Chain and Logistics, Organizational Development, Software Engineering, Agile Management, Planning, Operations Management, Sales, Strategy and Operations, Culture, Leadership and Management, Business Process Management, Communication, Project Management, Project, Software Engineering Tools, Entrepreneurship, Change Management, Leadership, Organizational Structure, Business Psychology']
#  Human Resources
#  Supply Chain and Logistics
#  Organizational Development
#  Software Engineering
#  Agile Management
#  Planning
#  Operations Management
#  Sales
#  Strategy and Operations
#  Culture
#  Leadership and Management
#  Business Process Management
#  Communication
#  Project Management
#  Project
#  Software Engineering Tools
#  Entrepreneurship
#  Change Management
#  Leadership
#  Organizational Structure
#  Business Psychology
# ========================================================
# job= Senior Analyst
# Chosen link :  https://www.coursera.org/courses?query=business%20analysis
# goto scrape 3
# scrape2
# total number of cards on page = 12
# num= below  1
# ------------------ Skills you'll gain: Business Analysis, Strategy and Operations, Entrepreneurship, Business Process Management, Analysis, Process, Business Process, Process Analysis
# ------------------- Business Analysis & Process Management
# ["Skills you'll gain", ' Business Analysis, Strategy and Operations, Entrepreneurship, Business Process Management, Analysis, Process, Business Process, Process Analysis']
#  Business Analysis
#  Strategy and Operations
#  Entrepreneurship
#  Business Process Management
#  Analysis
#  Process
#  Business Process
#  Process Analysis
# num= below  2
# ------------------ Skills you'll gain: Algorithms, Application Development, Bias, Big Data, Budget Management, Business Analysis, Business Communication, Change Management, Cloud Computing, Communication, Computational Logic, Computer Architecture, Computer Networking, Computer Programming, Computer Programming Tools, Cryptography, Data Analysis, Data Analysis Software, Data Management, Data Mining, Data Model, Data Structures, Data Visualization, Data Visualization Software, Database Administration, Database Design, Databases, Decision Making, Design and Product, Distributed Computing Architecture, Entrepreneurship, Extract, Transform, Load, Feature Engineering, Finance, Financial Analysis, Full-Stack Web Development, General Statistics, Interactive Data Visualization, Leadership and Management, Machine Learning, Mathematical Theory & Analysis, Mathematics, Network Security, Other Programming Languages, Plot (Graphics), Privacy, Probability & Statistics, Problem Solving, Product Design, Programming Principles, Project Management, R Programming, Research and Design, SQL, Security, Security Engineering, Security Strategy, Small Data, Software Engineering, Software Security, Spreadsheet Software, Statistical Analysis, Statistical Programming, Storytelling, Strategy and Operations, Theoretical Computer Science, Visual Design, Web Development
# ------------------- Google Data Analytics
# ["Skills you'll gain", ' Algorithms, Application Development, Bias, Big Data, Budget Management, Business Analysis, Business Communication, Change Management, Cloud Computing, Communication, Computational Logic, Computer Architecture, Computer Networking, Computer Programming, Computer Programming Tools, Cryptography, Data Analysis, Data Analysis Software, Data Management, Data Mining, Data Model, Data Structures, Data Visualization, Data Visualization Software, Database Administration, Database Design, Databases, Decision Making, Design and Product, Distributed Computing Architecture, Entrepreneurship, Extract, Transform, Load, Feature Engineering, Finance, Financial Analysis, Full-Stack Web Development, General Statistics, Interactive Data Visualization, Leadership and Management, Machine Learning, Mathematical Theory & Analysis, Mathematics, Network Security, Other Programming Languages, Plot (Graphics), Privacy, Probability & Statistics, Problem Solving, Product Design, Programming Principles, Project Management, R Programming, Research and Design, SQL, Security, Security Engineering, Security Strategy, Small Data, Software Engineering, Software Security, Spreadsheet Software, Statistical Analysis, Statistical Programming, Storytelling, Strategy and Operations, Theoretical Computer Science, Visual Design, Web Development']
#  Algorithms
#  Application Development
#  Bias
#  Big Data
#  Budget Management
#  Business Analysis
#  Business Communication
#  Change Management
#  Cloud Computing
#  Communication
#  Computational Logic
#  Computer Architecture
#  Computer Networking
#  Computer Programming
#  Computer Programming Tools
#  Cryptography
#  Data Analysis
#  Data Analysis Software
#  Data Management
#  Data Mining
#  Data Model
#  Data Structures
#  Data Visualization
#  Data Visualization Software
#  Database Administration
#  Database Design
#  Databases
#  Decision Making
#  Design and Product
#  Distributed Computing Architecture
#  Entrepreneurship
#  Extract
#  Transform
#  Load
#  Feature Engineering
#  Finance
#  Financial Analysis
#  Full-Stack Web Development
#  General Statistics
#  Interactive Data Visualization
#  Leadership and Management
#  Machine Learning
#  Mathematical Theory & Analysis
#  Mathematics
#  Network Security
#  Other Programming Languages
#  Plot (Graphics)
#  Privacy
#  Probability & Statistics
#  Problem Solving
#  Product Design
#  Programming Principles
#  Project Management
#  R Programming
#  Research and Design
#  SQL
#  Security
#  Security Engineering
#  Security Strategy
#  Small Data
#  Software Engineering
#  Software Security
#  Spreadsheet Software
#  Statistical Analysis
#  Statistical Programming
#  Storytelling
#  Strategy and Operations
#  Theoretical Computer Science
#  Visual Design
#  Web Development
# num= below  3
# ------------------ Skills you'll gain: Accounting, Analysis, Big Data, Business Analysis, Business Analytics, Business Psychology, Collaboration, Communication, Computational Logic, Computer Programming, Computer Programming Tools, Customer Analysis, Data Analysis, Data Analysis Software, Data Management, Data Structures, Decision Making, Entrepreneurship, Financial Accounting, Financial Analysis, Forecasting, General Statistics, Human Resources, Leadership and Management, Marketing, Mathematical Theory & Analysis, Mathematics, Microsoft Excel, Network Analysis, People Analysis, People Development, Performance, Performance Management, Predictive Analytics, Probability & Statistics, Regression, Regression Analysis, Sales, Spreadsheet Software, Statistical Analysis, Strategy, Strategy and Operations, Talent Management, Theoretical Computer Science
# ------------------- Business Analytics
# ["Skills you'll gain", ' Accounting, Analysis, Big Data, Business Analysis, Business Analytics, Business Psychology, Collaboration, Communication, Computational Logic, Computer Programming, Computer Programming Tools, Customer Analysis, Data Analysis, Data Analysis Software, Data Management, Data Structures, Decision Making, Entrepreneurship, Financial Accounting, Financial Analysis, Forecasting, General Statistics, Human Resources, Leadership and Management, Marketing, Mathematical Theory & Analysis, Mathematics, Microsoft Excel, Network Analysis, People Analysis, People Development, Performance, Performance Management, Predictive Analytics, Probability & Statistics, Regression, Regression Analysis, Sales, Spreadsheet Software, Statistical Analysis, Strategy, Strategy and Operations, Talent Management, Theoretical Computer Science']
#  Accounting
#  Analysis
#  Big Data
#  Business Analysis
#  Business Analytics
#  Business Psychology
#  Collaboration
#  Communication
#  Computational Logic
#  Computer Programming
#  Computer Programming Tools
#  Customer Analysis
#  Data Analysis
#  Data Analysis Software
#  Data Management
#  Data Structures
#  Decision Making
#  Entrepreneurship
#  Financial Accounting
#  Financial Analysis
#  Forecasting
#  General Statistics
#  Human Resources
#  Leadership and Management
#  Marketing
#  Mathematical Theory & Analysis
#  Mathematics
#  Microsoft Excel
#  Network Analysis
#  People Analysis
#  People Development
#  Performance
#  Performance Management
#  Predictive Analytics
#  Probability & Statistics
#  Regression
#  Regression Analysis
#  Sales
#  Spreadsheet Software
#  Statistical Analysis
#  Strategy
#  Strategy and Operations
#  Talent Management
#  Theoretical Computer Science
# ========================================================
# job= GS Cultural Secretary
# Chosen link :  https://www.thinkimpact.com/coursera-review/
# Landed on coursera course scrape1
#
# ========================================================
# job= Report analyst
# Chosen link :  https://www.coursera.org/professional-certificates/google-data-analytics
# Landed on coursera course scrape1
#
# Spreadsheet
# Data Cleansing
# Data Analysis
# Data Visualization (DataViz)
# SQL
# Questioning
# Decision-Making
# Problem Solving
# Metadata
#
#
#
# ''''''''''''''''''''''''''''''''''''''''''''''
# ========================================================
# job= Technical support manager
# Chosen link :  https://www.coursera.org/professional-certificates/google-it-support
# Landed on coursera course scrape1
#
# Debugging
# Encryption Algorithms and Techniques
# Customer Service
# Network Protocols
# Cloud Computing
# Binary Code
#
#
#
#
#
#
# ''''''''''''''''''''''''''''''''''''''''''''''
# ========================================================
# job= Systems engineer
# Chosen link :  https://www.coursera.org/learn/systems-engineering
# Landed on coursera course scrape1
#
# ========================================================
# job= Graduate engineer
# Chosen link :  https://www.coursera.org/courses?query=engineering
# goto scrape 3
# scrape2
# total number of cards on page = 12
# num= below  1
# ------------------ Free
# ------------------- Introduction to Engineering Mechanics
# ['Free']
# num= below  2
# ------------------ Skills you'll gain: Accounting, Communication, Cost, Entrepreneurship, Estimation, Finance, Generally Accepted Accounting Principles (GAAP), Human Resources, Leadership Development, Leadership and Management, Planning, Probability & Statistics, Procurement, Project, Project Management, Project Planning, Risk, Risk Management, Schedule, Statistical Tests, Strategy and Operations, Supply Chain and Logistics, Time Management
# ------------------- Engineering Project Management
# ["Skills you'll gain", ' Accounting, Communication, Cost, Entrepreneurship, Estimation, Finance, Generally Accepted Accounting Principles (GAAP), Human Resources, Leadership Development, Leadership and Management, Planning, Probability & Statistics, Procurement, Project, Project Management, Project Planning, Risk, Risk Management, Schedule, Statistical Tests, Strategy and Operations, Supply Chain and Logistics, Time Management']
#  Accounting
#  Communication
#  Cost
#  Entrepreneurship
#  Estimation
#  Finance
#  Generally Accepted Accounting Principles (GAAP)
#  Human Resources
#  Leadership Development
#  Leadership and Management
#  Planning
#  Probability & Statistics
#  Procurement
#  Project
#  Project Management
#  Project Planning
#  Risk
#  Risk Management
#  Schedule
#  Statistical Tests
#  Strategy and Operations
#  Supply Chain and Logistics
#  Time Management
# num= below  3
# ------------------ Free
# ------------------- Introduction to Thermodynamics: Transferring Energy from Here to There
# ['Free']
# ========================================================
# job= Test engineer
# Chosen link :  https://www.coursera.org/courses?query=software%20testing
# goto scrape 3
# scrape2
# total number of cards on page = 12
# num= below  1
# ------------------ Skills you'll gain: .Properties, Communication, Computer Programming, Computer Programming Tools, Java Programming, Journalism, Mobile Development, Programming Principles, Software, Software Engineering, Software Testing, Unit Testing
# ------------------- Software Testing and Automation
# ...
# ------------------- IBM Full Stack Software Developer
# ["Skills you'll gain", ' Application Development, Back-End Web Development, BlockChain, Cloud Applications, Cloud Computing, Cloud Foundry, Cloud Infrastructure, Cloud Platforms, Cloud Storage, Computational Logic, Computer Architecture, Computer Graphics, Computer Networking, Computer Programming, Computer Programming Tools, Continuous Delivery, Continuous Integration, Data Management, Database Administration, Database Application, Database Design, Databases, DevOps, Devops Tools, Distributed Computing Architecture, Extract, Transform, Load, Finance, Front-End Web Development, Full-Stack Web Development, Github, HTML and CSS, Human Computer Interaction, IBM Cloud, Interactive Design, Javascript, Kubernetes, Mathematical Theory & Analysis, Mathematics, Network Architecture, Network Security, NoSQL, Operating Systems, Other Web Frameworks, Python Programming, React (web framework), SQL, Security Engineering, Software, Software Architecture, Software As A Service, Software Engineering, Software Framework, Software Testing, Statistical Programming, System Programming, Systems Design, Theoretical Computer Science, Web Design, Web Development, Web Development Tools']
#  Application Development
#  Back-End Web Development
#  BlockChain
#  Cloud Applications
#  Cloud Computing
#  Cloud Foundry
#  Cloud Infrastructure
#  Cloud Platforms
#  Cloud Storage
#  Computational Logic
#  Computer Architecture
#  Computer Graphics
#  Computer Networking
#  Computer Programming
#  Computer Programming Tools
#  Continuous Delivery
#  Continuous Integration
#  Data Management
#  Database Administration
#  Database Application
#  Database Design
#  Databases
#  DevOps
#  Devops Tools
#  Distributed Computing Architecture
#  Extract
#  Transform
#  Load
#  Finance
#  Front-End Web Development
#  Full-Stack Web Development
#  Github
#  HTML and CSS
#  Human Computer Interaction
#  IBM Cloud
#  Interactive Design
#  Javascript
#  Kubernetes
#  Mathematical Theory & Analysis
#  Mathematics
#  Network Architecture
#  Network Security
#  NoSQL
#  Operating Systems
#  Other Web Frameworks
#  Python Programming
#  React (web framework)
#  SQL
#  Security Engineering
#  Software
#  Software Architecture
#  Software As A Service
#  Software Engineering
#  Software Framework
#  Software Testing
#  Statistical Programming
#  System Programming
#  Systems Design
#  Theoretical Computer Science
#  Web Design
#  Web Development
#  Web Development Tools
# ========================================================
# job= Team leader
# Chosen link :  https://www.coursera.org/specializations/leading-teams
# Landed on coursera course scrape1
#
# Vision Alignment
# Talent Management
# Goals and Rewards
# Motivate Employees
# Leadership
# goal setting
# Communication
#
#
#
#
#
# ''''''''''''''''''''''''''''''''''''''''''''''
# ========================================================
# job= Team manager
# Chosen link :  https://www.coursera.org/specializations/leading-teams
# Landed on coursera course scrape1
#
# Vision Alignment
# Talent Management
# Goals and Rewards
# Motivate Employees
# Leadership
# goal setting
# Communication
#
#
#
#
#
# ''''''''''''''''''''''''''''''''''''''''''''''
# ========================================================
# job= Operations manager
# Chosen link :  https://www.coursera.org/learn/wharton-operations
# Landed on coursera course scrape1
#
# Process Management
# Operations Management
# Six Sigma
# Inventory
# ''''''''''''''''''''''''''''''''''''''''''''''
# ========================================================
# job= Accountant
# Chosen link :  https://www.coursera.org/courses?query=accounting
# goto scrape 3
# scrape2
# total number of cards on page = 12
# num= below  1
# ------------------ Skills you'll gain: Accounting, Accounts Payable and Receivable, Analysis, Budget Management, Business Analysis, Corporate Bond, Data Analysis, Entrepreneurship, Finance, Financial Accounting, Financial Analysis, General Accounting, Generally Accepted Accounting Principles (GAAP), Investment, Investment Management, Taxes
# ------------------- Introduction to Finance and Accounting
# ["Skills you'll gain", ' Accounting, Accounts Payable and Receivable, Analysis, Budget Management, Business Analysis, Corporate Bond, Data Analysis, Entrepreneurship, Finance, Financial Accounting, Financial Analysis, General Accounting, Generally Accepted Accounting Principles (GAAP), Investment, Investment Management, Taxes']
#  Accounting
#  Accounts Payable and Receivable
#  Analysis
#  Budget Management
#  Business Analysis
#  Corporate Bond
#  Data Analysis
#  Entrepreneurship
#  Finance
#  Financial Accounting
#  Financial Analysis
#  General Accounting
#  Generally Accepted Accounting Principles (GAAP)
#  Investment
#  Investment Management
#  Taxes
# num= below  2
# ------------------ Skills you'll gain: Account Management, Accounting, Accounts Payable and Receivable, Analysis, Audit, Budget Management, Cost Accounting, Design and Product, Entrepreneurship, Finance, Financial Accounting, Flow Network, General Accounting, Generally Accepted Accounting Principles (GAAP), Leadership and Management, Management Accounting, Product Management, Sales, Strategy and Operations
# ------------------- Fundamentals of Accounting
# ["Skills you'll gain", ' Account Management, Accounting, Accounts Payable and Receivable, Analysis, Audit, Budget Management, Cost Accounting, Design and Product, Entrepreneurship, Finance, Financial Accounting, Flow Network, General Accounting, Generally Accepted Accounting Principles (GAAP), Leadership and Management, Management Accounting, Product Management, Sales, Strategy and Operations']
#  Account Management
#  Accounting
#  Accounts Payable and Receivable
#  Analysis
#  Audit
#  Budget Management
#  Cost Accounting
#  Design and Product
#  Entrepreneurship
#  Finance
#  Financial Accounting
#  Flow Network
#  General Accounting
#  Generally Accepted Accounting Principles (GAAP)
#  Leadership and Management
#  Management Accounting
#  Product Management
#  Sales
#  Strategy and Operations
# num= below  3
# ------------------ Skills you'll gain: Accounting, Accounts Payable and Receivable, Audit, Business Analysis, Cost Accounting, Data Analysis, Design and Product, Finance, Financial Accounting, Financial Analysis, General Accounting, Generally Accepted Accounting Principles (GAAP), Inventory Management, Leadership and Management, Merchandising, Payments, Product Lifecycle, Sales, Supply Chain and Logistics, Taxes
# ------------------- Intuit Bookkeeping
# ["Skills you'll gain", ' Accounting, Accounts Payable and Receivable, Audit, Business Analysis, Cost Accounting, Data Analysis, Design and Product, Finance, Financial Accounting, Financial Analysis, General Accounting, Generally Accepted Accounting Principles (GAAP), Inventory Management, Leadership and Management, Merchandising, Payments, Product Lifecycle, Sales, Supply Chain and Logistics, Taxes']
#  Accounting
#  Accounts Payable and Receivable
#  Audit
#  Business Analysis
#  Cost Accounting
#  Data Analysis
#  Design and Product
#  Finance
#  Financial Accounting
#  Financial Analysis
#  General Accounting
#  Generally Accepted Accounting Principles (GAAP)
#  Inventory Management
#  Leadership and Management
#  Merchandising
#  Payments
#  Product Lifecycle
#  Sales
#  Supply Chain and Logistics
#  Taxes
# ========================================================
# job= Marketing manager
# Chosen link :  https://www.coursera.org/learn/marketing-management
# Landed on coursera course scrape1
#
# Market Analysis
# Marketing
# Marketing Strategy
# Marketing Mix
# ''''''''''''''''''''''''''''''''''''''''''''''
# ========================================================
# job= HR
# Chosen link :  https://www.coursera.org/courses?query=hr
# goto scrape 3
# scrape2
# total number of cards on page = 12
# num= below  1
# ------------------ Skills you'll gain: Analysis, Benefits, Compensation, Employment, Entrepreneurship, Human Resources, Leadership, Leadership and Management, Marketing, Onboarding, People Management, Performance, Performance Management, Recruitment, Sales, Strategy, Strategy and Operations
# ------------------- Human Resource Management: HR for People Managers
# ["Skills you'll gain", ' Analysis, Benefits, Compensation, Employment, Entrepreneurship, Human Resources, Leadership, Leadership and Management, Marketing, Onboarding, People Management, Performance, Performance Management, Recruitment, Sales, Strategy, Strategy and Operations']
#  Analysis
#  Benefits
#  Compensation
#  Employment
#  Entrepreneurship
#  Human Resources
#  Leadership
#  Leadership and Management
#  Marketing
#  Onboarding
#  People Management
#  Performance
#  Performance Management
#  Recruitment
#  Sales
#  Strategy
#  Strategy and Operations
# num= below  2
# ------------------ Skills you'll gain: Behavior, Brand, Business Psychology, Communication, Conflict Management, Culture, Entrepreneurship, Human Resources, Leadership and Management, Marketing, Motivation, Resource, Sales, Strategy, Strategy and Operations
# ------------------- Leading: Human Resource Management and Leadership
# ["Skills you'll gain", ' Behavior, Brand, Business Psychology, Communication, Conflict Management, Culture, Entrepreneurship, Human Resources, Leadership and Management, Marketing, Motivation, Resource, Sales, Strategy, Strategy and Operations']
#  Behavior
#  Brand
#  Business Psychology
#  Communication
#  Conflict Management
#  Culture
#  Entrepreneurship
#  Human Resources
#  Leadership and Management
#  Marketing
#  Motivation
#  Resource
#  Sales
#  Strategy
#  Strategy and Operations
# num= below  3
# ------------------ Skills you'll gain: Human Resources, Data Visualization, Analysis, Employee Relations, Data Analysis, Resource, Business Analysis, Analytics, Storytelling, Communication, People Analysis
# ------------------- Human Resources Analytics
# ["Skills you'll gain", ' Human Resources, Data Visualization, Analysis, Employee Relations, Data Analysis, Resource, Business Analysis, Analytics, Storytelling, Communication, People Analysis']
#  Human Resources
#  Data Visualization
#  Analysis
#  Employee Relations
#  Data Analysis
#  Resource
#  Business Analysis
#  Analytics
#  Storytelling
#  Communication
#  People Analysis
# ========================================================
# job= Data scientist
# Chosen link :  https://www.coursera.org/browse/data-science
# Landed on coursera course scrape1
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# Untitled-1.ipynb Cell 15 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=0'>1</a> main()
#
# Untitled-1.ipynb Cell 15 in main()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=2'>3</a> init()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=3'>4</a> for job in designations:
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=4'>5</a>     #https://www.google.com/search?q=
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=5'>6</a>     Coursera_links = fetch(job)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=6'>7</a>     Coursera_links= remove_unwanted_urls(Coursera_links)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=8'>9</a>     if(len(Coursera_links)>0):
#
# Untitled-1.ipynb Cell 15 in fetch(job)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=9'>10</a>                                                              ##print("result =",results)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=10'>11</a> for result in results:
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=11'>12</a>                                                              ##print(result.get_attribute("href"))
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=12'>13</a>         link= result.get_attribute("href")
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=13'>14</a>         if(link is not None):
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=14'>15</a>                                                              ## print(type(link))
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=15'>16</a>                                                             ##print(link)
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000013untitled?line=16'>17</a>            all_links.append(link)
#
# File c:\Users\User\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:172, in WebElement.get_attribute(self, name)
#     170 if getAttribute_js is None:
#     171     _load_js()
# --> 172 attribute_value = self.parent.execute_script(
#     173     "return (%s).apply(null, arguments);" % getAttribute_js,
#     174     self, name)
#     175 return attribute_value
#
# File c:\Users\User\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:493, in WebDriver.execute_script(self, script, *args)
#     490 converted_args = list(args)
#     491 command = Command.W3C_EXECUTE_SCRIPT
# --> 493 return self.execute(command, {
#     494     'script': script,
#     495     'args': converted_args})['value']
#
# File c:\Users\User\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:435, in WebDriver.execute(self, driver_command, params)
#     433 response = self.command_executor.execute(driver_command, params)
#     434 if response:
# --> 435     self.error_handler.check_response(response)
#     436     response['value'] = self._unwrap_value(
#     437         response.get('value', None))
#     438     return response
#
# File c:\Users\User\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# StaleElementReferenceException: Message: stale element reference: element is not attached to the page document
#   (Session info: chrome=104.0.5112.57)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x0054AF23+2207523]
# 	Ordinal0 [0x004E30E1+1781985]
# 	Ordinal0 [0x003F3FE8+802792]
# 	Ordinal0 [0x003F69F4+813556]
# 	Ordinal0 [0x003F68B2+813234]
# 	Ordinal0 [0x003F722A+815658]
# 	Ordinal0 [0x0044E439+1172537]
# 	Ordinal0 [0x0043D5EC+1103340]
# 	Ordinal0 [0x0044D9F2+1169906]
# 	Ordinal0 [0x0043D406+1102854]
# 	Ordinal0 [0x004175F0+947696]
# 	Ordinal0 [0x004184E6+951526]
# 	GetHandleVerifier [0x007F2A12+2733954]
# 	GetHandleVerifier [0x007E4E28+2677656]
# 	GetHandleVerifier [0x005D46EA+513114]
# 	GetHandleVerifier [0x005D3796+509190]
# 	Ordinal0 [0x004E9CEB+1809643]
# 	Ordinal0 [0x004EE448+1827912]
# 	Ordinal0 [0x004EE535+1828149]
# 	Ordinal0 [0x004F7960+1866080]
# 	BaseThreadInitThunk [0x755EF989+25]
# 	RtlGetAppContainerNamedObjectPath [0x77197084+228]
# 	RtlGetAppContainerNamedObjectPath [0x77197054+180]
